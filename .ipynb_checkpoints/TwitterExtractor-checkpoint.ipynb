# %% [markdown]
# <h1 style="color:red">Import data from mongo</h1>

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient()
db = client.movies
collection = db.movies
data = pd.DataFrame(list(collection.find()))

# %%
data.head(13)
# Out:
#                          _id       bad      best      good     great  \
# 0   5822e0bec42bc91c1c9bdd03  0.012868  0.027711  0.084271  0.033756
# 1   5822e0bec42bc91c1c9bdd04  0.006738  0.001684  0.007861  0.004492
# 2   5822e0bec42bc91c1c9bdd05  0.000998  0.008423  0.038016  0.006705
# 3   5822e0bec42bc91c1c9bdd06  0.000000  0.006154  0.026667  0.082051
# 4   5822e0bec42bc91c1c9bdd07  0.003304  0.010307  0.016522  0.011172
# 5   5822e0bec42bc91c1c9bdd08  0.011862  0.004486  0.005183  0.009071
# 6   5822e0bec42bc91c1c9bdd09  0.009572  0.009305  0.018977  0.003202
# 7   5822e0bec42bc91c1c9bdd0a  0.008501  0.002834  0.015198  0.006440
# 8   5822e0bec42bc91c1c9bdd0b  0.002435  0.014507  0.051885  0.058873
# 9   5822e0bec42bc91c1c9bdd0c  0.000000  0.015890  0.008475  0.028602
# 10  5822e0bec42bc91c1c9bdd0d  0.000178  0.001334  0.003870  0.003292
# 11  5822e0bec42bc91c1c9bdd0e  0.002503  0.092152  0.020974  0.053112
# 12  5822e0bec42bc91c1c9bdd0f  0.004604  0.023919  0.022358  0.019260
#
#          gross                     query  retweets  tweets     worst
# 0   24710273.0            #TheAccountant     10957   16708  0.000718
# 1    2182216.0                 #MaxSteel      1301    1781  0.002246
# 2   11767210.0         #KevinHartWhatNow     14787   18045  0.000000
# 3     707021.0        #PricelessTheMovie       511     975  0.000000
# 4   28501448.0           #MadeaHalloween      9847   12710  0.000315
# 5   22872490.0         #JackReacherMovie      8783   10032  0.000199
# 6   14065500.0               #OuijaMovie     12413   29983  0.000334
# 7    5461475.0  #KeepingUpWithTheJoneses      2638    3882  0.001030
# 8   14860425.0             #InfernoMovie      7215    9444  0.004024
# 9      44725.0              #GimmeDanger       759     944  0.000000
# 10  46581142.0         #DreamWorksTrolls     12690   22481  0.000133
# 11  15190758.0             #HacksawRidge     10091   14780  0.000271
# 12  85058311.0            #DoctorStrange     85249  125547  0.000422

# %% [markdown]
# <h1 style="color:blue">Make table readable</h1>

# %%
del data['_id']
query = data['query']
data.drop(labels=['query'], axis=1, inplace=True)
data.insert(0, 'query', query)
tweets = data['tweets']
data.drop(labels=['tweets'], axis=1, inplace=True)
data.insert(1, 'tweets', tweets)
retweets = data['retweets']
data.drop(labels=['retweets'], axis=1, inplace=True)
data.insert(2, 'retweets', retweets)
worst = data['worst']
data.drop(labels=['worst'], axis=1, inplace=True)
data.insert(4, 'worst', worst)
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 1                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 2          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 3         #PricelessTheMovie     975       511  0.000000  0.000000  0.006154
# 4            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 5          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 6                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 7   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 8              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 9               #GimmeDanger     944       759  0.000000  0.000000  0.015890
# 10         #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 11             #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 12            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
#
#         good     great       gross
# 0   0.084271  0.033756  24710273.0
# 1   0.007861  0.004492   2182216.0
# 2   0.038016  0.006705  11767210.0
# 3   0.026667  0.082051    707021.0
# 4   0.016522  0.011172  28501448.0
# 5   0.005183  0.009071  22872490.0
# 6   0.018977  0.003202  14065500.0
# 7   0.015198  0.006440   5461475.0
# 8   0.051885  0.058873  14860425.0
# 9   0.008475  0.028602     44725.0
# 10  0.003870  0.003292  46581142.0
# 11  0.020974  0.053112  15190758.0
# 12  0.022358  0.019260  85058311.0

# %% [markdown]
# <h2>Plotting</h2>

# %%
import matplotlib.pyplot as plt
plt.ylabel('gross')
plt.xlabel('bad')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['bad'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('worst')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['worst'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('good')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['good'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('great')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['great'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('best')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['best'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('tweets')
plt.scatter(data['tweets'], data['gross'])
plt.show()

# %%
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 1                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 2          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 3         #PricelessTheMovie     975       511  0.000000  0.000000  0.006154
# 4            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 5          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 6                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 7   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 8              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 9               #GimmeDanger     944       759  0.000000  0.000000  0.015890
# 10         #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 11             #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 12            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
#
#         good     great       gross
# 0   0.084271  0.033756  24710273.0
# 1   0.007861  0.004492   2182216.0
# 2   0.038016  0.006705  11767210.0
# 3   0.026667  0.082051    707021.0
# 4   0.016522  0.011172  28501448.0
# 5   0.005183  0.009071  22872490.0
# 6   0.018977  0.003202  14065500.0
# 7   0.015198  0.006440   5461475.0
# 8   0.051885  0.058873  14860425.0
# 9   0.008475  0.028602     44725.0
# 10  0.003870  0.003292  46581142.0
# 11  0.020974  0.053112  15190758.0
# 12  0.022358  0.019260  85058311.0

# %%
data['badsquare'] = data.bad**2
data['worstsquare'] = data.worst**2
data['bestsquare'] = data.best**2
data['goodsquare'] = data.good**2
data['greatsquare'] = data.great**2
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 1                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 2          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 3         #PricelessTheMovie     975       511  0.000000  0.000000  0.006154
# 4            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 5          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 6                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 7   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 8              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 9               #GimmeDanger     944       759  0.000000  0.000000  0.015890
# 10         #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 11             #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 12            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
#
#         good     great       gross     badsquare   worstsquare  bestsquare  \
# 0   0.084271  0.033756  24710273.0  1.655877e-04  5.158383e-07    0.000768
# 1   0.007861  0.004492   2182216.0  4.539778e-05  5.044198e-06    0.000003
# 2   0.038016  0.006705  11767210.0  9.950187e-07  0.000000e+00    0.000071
# 3   0.026667  0.082051    707021.0  0.000000e+00  0.000000e+00    0.000038
# 4   0.016522  0.011172  28501448.0  1.091962e-05  9.904416e-08    0.000106
# 5   0.005183  0.009071  22872490.0  1.407080e-04  3.974522e-08    0.000020
# 6   0.018977  0.003202  14065500.0  9.162492e-05  1.112371e-07    0.000087
# 7   0.015198  0.006440   5461475.0  7.226314e-05  1.061717e-06    0.000008
# 8   0.051885  0.058873  14860425.0  5.931216e-06  1.619031e-05    0.000210
# 9   0.008475  0.028602     44725.0  0.000000e+00  0.000000e+00    0.000252
# 10  0.003870  0.003292  46581142.0  3.165838e-08  1.780784e-08    0.000002
# 11  0.020974  0.053112  15190758.0  6.266926e-06  7.324384e-08    0.008492
# 12  0.022358  0.019260  85058311.0  2.119547e-05  1.782129e-07    0.000572
#
#     goodsquare  greatsquare
# 0     0.007102     0.001139
# 1     0.000062     0.000020
# 2     0.001445     0.000045
# 3     0.000711     0.006732
# 4     0.000273     0.000125
# 5     0.000027     0.000082
# 6     0.000360     0.000010
# 7     0.000231     0.000041
# 8     0.002692     0.003466
# 9     0.000072     0.000818
# 10    0.000015     0.000011
# 11    0.000440     0.002821
# 12    0.000500     0.000371

# %%
gross = data['gross']
data.drop(labels=['gross'], axis=1, inplace=True)
data.insert(13, 'gross', gross)
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 1                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 2          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 3         #PricelessTheMovie     975       511  0.000000  0.000000  0.006154
# 4            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 5          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 6                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 7   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 8              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 9               #GimmeDanger     944       759  0.000000  0.000000  0.015890
# 10         #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 11             #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 12            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
#
#         good     great     badsquare   worstsquare  bestsquare  goodsquare  \
# 0   0.084271  0.033756  1.655877e-04  5.158383e-07    0.000768    0.007102
# 1   0.007861  0.004492  4.539778e-05  5.044198e-06    0.000003    0.000062
# 2   0.038016  0.006705  9.950187e-07  0.000000e+00    0.000071    0.001445
# 3   0.026667  0.082051  0.000000e+00  0.000000e+00    0.000038    0.000711
# 4   0.016522  0.011172  1.091962e-05  9.904416e-08    0.000106    0.000273
# 5   0.005183  0.009071  1.407080e-04  3.974522e-08    0.000020    0.000027
# 6   0.018977  0.003202  9.162492e-05  1.112371e-07    0.000087    0.000360
# 7   0.015198  0.006440  7.226314e-05  1.061717e-06    0.000008    0.000231
# 8   0.051885  0.058873  5.931216e-06  1.619031e-05    0.000210    0.002692
# 9   0.008475  0.028602  0.000000e+00  0.000000e+00    0.000252    0.000072
# 10  0.003870  0.003292  3.165838e-08  1.780784e-08    0.000002    0.000015
# 11  0.020974  0.053112  6.266926e-06  7.324384e-08    0.008492    0.000440
# 12  0.022358  0.019260  2.119547e-05  1.782129e-07    0.000572    0.000500
#
#     greatsquare       gross
# 0      0.001139  24710273.0
# 1      0.000020   2182216.0
# 2      0.000045  11767210.0
# 3      0.006732    707021.0
# 4      0.000125  28501448.0
# 5      0.000082  22872490.0
# 6      0.000010  14065500.0
# 7      0.000041   5461475.0
# 8      0.003466  14860425.0
# 9      0.000818     44725.0
# 10     0.000011  46581142.0
# 11     0.002821  15190758.0
# 12     0.000371  85058311.0

# %%
del data['query']
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(total_data[:,:13], total_data[:, 13], test_size=0.8, random_state=0)
X_test
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-66-0619851dfdee> in <module>()
#       1 del data['query']
# ----> 2 from sklearn.cross_validation import train_test_split
#       3 X_train, X_test, y_train, y_test = train_test_split(total_data[:,:13], total_data[:, 13], test_size=0.8, random_state=0)
#       4 X_test
#
# c:\python27\lib\site-packages\sklearn\__init__.py in <module>()
#      54     # process, as it may not be compiled yet
#      55 else:
# ---> 56     from . import __check_build
#      57     from .base import clone
#      58     __check_build  # avoid flakes unused variable error
#
# ImportError: cannot import name __check_build

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
clf = LinearRegression()
clf.fit(X_train, y_train)

print (clf.intercept_)
print (clf.coef_)
# Out:
# -364490.525901
# [  1.50076392e+03   5.11017292e-04  -3.65277800e-05   8.08215738e-03
#    3.19626734e-03   2.91092563e-03]
