# %% [markdown]
# <h1 style="color:red">Import data from mongo</h1>

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
client = MongoClient()
db = client.movies
collection = db.movies
data = pd.DataFrame(list(collection.find()))

# %%
data.head(13)
# Out:
#                          _id       bad      best      good     great  \
# 0   5822e0bec42bc91c1c9bdd04  0.006738  0.001684  0.007861  0.004492
# 1   5822e0bec42bc91c1c9bdd05  0.000998  0.008423  0.038016  0.006705
# 2   5822e0bec42bc91c1c9bdd08  0.011862  0.004486  0.005183  0.009071
# 3   5822e0bec42bc91c1c9bdd07  0.003304  0.010307  0.016522  0.011172
# 4   5822e0bec42bc91c1c9bdd09  0.009572  0.009305  0.018977  0.003202
# 5   5822e0bec42bc91c1c9bdd0a  0.008501  0.002834  0.015198  0.006440
# 6   5822e0bec42bc91c1c9bdd0b  0.002435  0.014507  0.051885  0.058873
# 7   5822e0bec42bc91c1c9bdd03  0.012868  0.027711  0.084271  0.033756
# 8   5822e0bec42bc91c1c9bdd0d  0.000178  0.001334  0.003870  0.003292
# 9   5822e0bec42bc91c1c9bdd0e  0.002503  0.092152  0.020974  0.053112
# 10  5822e0bec42bc91c1c9bdd0f  0.004604  0.023919  0.022358  0.019260
# 11  5822e0bec42bc91c1c9bdd0c  0.000000  0.015890  0.008475  0.028602
# 12  5822e0bec42bc91c1c9bdd06  0.000000  0.006154  0.026667  0.082051
#
# ...

# %% [markdown]
# <h1 style="color:blue">Make table readable</h1>

# %%
del data['_id']
query = data['query']
data.drop(labels=['query'], axis=1, inplace=True)
data.insert(0, 'query', query)
tweets = data['tweets']
data.drop(labels=['tweets'], axis=1, inplace=True)
data.insert(1, 'tweets', tweets)
retweets = data['retweets']
data.drop(labels=['retweets'], axis=1, inplace=True)
data.insert(2, 'retweets', retweets)
worst = data['worst']
data.drop(labels=['worst'], axis=1, inplace=True)
data.insert(4, 'worst', worst)
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 1          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 2          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 3            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 4                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 5   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 6              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 7             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 8          #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 9              #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 10            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
# ...

# %% [markdown]
# <h2>Plotting</h2>

# %%
import matplotlib.pyplot as plt
plt.ylabel('gross')
plt.xlabel('bad')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['bad'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('worst')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['worst'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('good')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['good'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('great')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['great'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('best')
plt.axis([0, 0.1, 0, 100000000])
plt.scatter(data['best'], data['gross'])
plt.show()

# %%
plt.ylabel('gross')
plt.xlabel('tweets')
plt.scatter(data['tweets'], data['gross'])
plt.show()

# %%
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 1          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 2          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 3            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 4                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 5   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 6              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 7             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 8          #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 9              #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 10            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
# ...

# %%
data['badsquare'] = data.bad**2
data['worstsquare'] = data.worst**2
data['bestsquare'] = data.best**2
data['goodsquare'] = data.good**2
data['greatsquare'] = data.great**2
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 1          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 2          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 3            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 4                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 5   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 6              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 7             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 8          #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 9              #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 10            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
# ...

# %%
gross = data['gross']
data.drop(labels=['gross'], axis=1, inplace=True)
data.insert(13, 'gross', gross)
data.head(13)
# Out:
#                        query  tweets  retweets       bad     worst      best  \
# 0                  #MaxSteel    1781      1301  0.006738  0.002246  0.001684
# 1          #KevinHartWhatNow   18045     14787  0.000998  0.000000  0.008423
# 2          #JackReacherMovie   10032      8783  0.011862  0.000199  0.004486
# 3            #MadeaHalloween   12710      9847  0.003304  0.000315  0.010307
# 4                #OuijaMovie   29983     12413  0.009572  0.000334  0.009305
# 5   #KeepingUpWithTheJoneses    3882      2638  0.008501  0.001030  0.002834
# 6              #InfernoMovie    9444      7215  0.002435  0.004024  0.014507
# 7             #TheAccountant   16708     10957  0.012868  0.000718  0.027711
# 8          #DreamWorksTrolls   22481     12690  0.000178  0.000133  0.001334
# 9              #HacksawRidge   14780     10091  0.002503  0.000271  0.092152
# 10            #DoctorStrange  125547     85249  0.004604  0.000422  0.023919
# ...

# %%
del data['query']

# %% [markdown]
# <h1 style="color:orange">Sklearn Stuff</h1>

# %%
total_data = data.values
from sklearn import preprocessing
scaled_data = preprocessing.scale(total_data)
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(scaled_data[:,:12], scaled_data[:,12], test_size=0.2, random_state=0)
X_train
# Out:
# array([[ 3.33733855,  3.37821723, -0.06511785, -0.29054671,  0.30689046,
#         -0.10564217, -0.21867331, -0.3990701 , -0.37073849, -0.11024099,
#         -0.30367098, -0.43247857],
#        [-0.33475134, -0.22882712,  1.58957601, -0.4907089 , -0.53361   ,
#         -0.90244945, -0.63451121,  1.77354101, -0.40249541, -0.35811688,
#         -0.55496907, -0.58190786],
#        [ 0.06098815, -0.04452662, -1.07412339, -0.54992996, -0.66989776,
#         -0.96338712, -0.87038456, -0.78380561, -0.40752665, -0.36635237,
#         -0.56128653, -0.61889448],
#        [-0.08002723,  0.0543928 , -0.88727909, -0.66982212, -0.36330403,
#          0.62079278, -0.73105601, -0.76629275, -0.41161079, -0.33529111,
#          0.19855074, -0.6012272 ],
#        [-0.12252893, -0.12627547,  1.81893045, -0.02455143,  0.47089093,
#          2.76674982,  0.37298152,  2.22582636, -0.29330564, -0.02232776,
#          3.20358026, -0.03461893],
# ...

# %%
y_train
# Out:
# 10    85058311.0
# 2     22872490.0
# 8     46581142.0
# 1     11767210.0
# 7     24710273.0
# 9     15190758.0
# 3     28501448.0
# 0      2182216.0
# 5      5461475.0
# 12      707021.0
# Name: gross, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics
clf = LinearRegression()
clf.fit(X_train, y_train)

print (clf.intercept_)
print (clf.coef_)
# Out:
# -0.046969827625
# [ 0.70162466  0.00916864 -0.0336913  -0.12881127  0.71714211 -1.94527398
#   0.73534166 -0.31684906 -0.59998159 -0.83923172  1.75297679 -0.77001181]
